# %% [markdown]
# ## Topic: Input and Output
# ### Definition
# Input allows the user to provide data to a program, while Output displays information to the user.
#
# ### Input
# - Taken using `input()` function
# - Always returns value as **string**
# - Must be converted to numeric type using `int()` or `float()` if needed
#
# ### Output
# - Done using `print()` function
# - Multiple values can be printed together
# - f-Strings or concatenation can be used for formatting

# %%
# Program 1: Basic input and output
name = input("Enter your name: ")
print("Hello,", name, "!")
# Out:
# Enter your name:  priya
# Hello, priya !

# %%
# Program 2: Adding two numbers using input()
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

result = num1 + num2
print("Sum =", result)
# Out:
# Enter first number:  23
# Enter second number:  34
# Sum = 57

# %%
# Program 4: Check if a number is even or odd
num = int(input("Enter a number: "))

if num % 2 == 0:
    print(num, "is Even")
else:
    print(num, "is Odd")
# Out:
# Enter a number:  6
# 6 is Even

# %%
# Program 5: Simple Interest Calculation
principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate of interest: "))
time = float(input("Enter time in years: "))

si = (principal * rate * time) / 100
print("Simple Interest =", si)
# Out:
# Enter principal amount:  33000
# Enter rate of interest:  7
# Enter time in years:  2
# Simple Interest = 4620.0

# %% [markdown]
# ## Conclusion
# In this topic, we learned how to take `input` from the user and show output using `print()`.
